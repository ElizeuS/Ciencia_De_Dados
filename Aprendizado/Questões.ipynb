# %%
import pandas as pd

# %%
dt = pd.read_csv("F:/Bibliotecas/Documentos/football-events/events.csv")

# %%
dt.columns
# Out:
# Index(['id_odsp', 'id_event', 'sort_order', 'time', 'text', 'event_type',
#        'event_type2', 'side', 'event_team', 'opponent', 'player', 'player2',
#        'player_in', 'player_out', 'shot_place', 'shot_outcome', 'is_goal',
#        'location', 'bodypart', 'assist_method', 'situation', 'fast_break'],
#       dtype='object')

# %%
##TRABALHANDO NOS VALORES DOS GOLS E TENTATIVAS

# %%
##Pegar colunas especificas do DataFrame, correspondente as finalizações
dct = dt[['id_odsp', 'id_event', 'sort_order', 'text', 'event_type', 'event_type2','side', 'event_team', 'opponent','player', 
            'player2', 'shot_place', 'shot_outcome', 'is_goal', 'location', 'bodypart', 'assist_method', 'situation']]

# %%
dt_tentativas = dct[(dct['event_type'] == 1) & (dct['is_goal'] == 0)]

# %%
dt_gols = dct[(dct['event_type'] == 1) & (dct['is_goal'] == 1) & (dct['shot_outcome'] >= 1)]

# %%
quant_tentativas = dt_tentativas.groupby(['event_team']).count()

# %%
quant_gols = dt_gols.groupby(['event_team']).count()

# %%
quant_tentativas.head()
# Out:
#                    id_odsp  id_event  sort_order  text  event_type  \
# event_team
# AC Ajaccio             992       992         992   992         992
# AC Milan              2736      2736        2736  2736        2736
# AJ Auxerre             400       400         400   400         400
# AS Monaco             1432      1432        1432  1432        1432
# AS Nancy Lorraine      970       970         970   970         970
#
#                    event_type2  side  opponent  player  player2  shot_place  \
# event_team
# AC Ajaccio                 686   992       992     992      686         992
# AC Milan                  1999  2736      2736    2736     1999        2736
# AJ Auxerre                 273   400       400     400      273         400
# AS Monaco                 1072  1432      1432    1432     1072        1432
# AS Nancy Lorraine          728   970       970     970      726         970
#
#                    shot_outcome  is_goal  location  bodypart  assist_method  \
# ...

# %%
quant = ((quant_gols['id_event'])/quant_tentativas['id_event'])

# %%
quant
# Out:
# event_team
# AC Ajaccio                    0.110887
# AC Milan                      0.116959
# AJ Auxerre                    0.115000
# AS Monaco                     0.159218
# AS Nancy Lorraine             0.089691
# AS Roma                       0.127947
# Alaves                        0.112583
# Almeria                       0.107246
# Angers                        0.090759
# Arsenal                       0.137050
# Aston Villa                   0.080449
# Atalanta                      0.100951
# Athletic Bilbao               0.122172
# Atletico Madrid               0.144079
# Barcelona                     0.216616
# Bastia                        0.115180
# Bayer Leverkusen              0.129366
# Bayern Munich                 0.167169
# Bologna                       0.088156
# Bordeaux                      0.113024
# Borussia Dortmund             0.153270
# Borussia Monchengladbach      0.139188
# Bournemouth                   0.118380
# Brest                         0.079576
# ...

# %%
##ACIMA A TENTATIVA DE RESPONDER A QUESTÃO 1 (EM ANDAMENTO)

# %%
##Guardando os valores de gols por cada partida
##goals_per_game = dgoal.groupby(['event_team', 'id_odsp']).count()

# %%
##goals_per_game.head()

# %%
##pegando a quantidade de gols por jogador
##dplayer = dgoal.groupby(['player']).count()

# %%
##dplayer.head()

# %%
dtt = pd.read_csv("F:/Bibliotecas/Documentos/football-events/ginf.csv")

# %%
dtt.columns
# Out:
# Index(['id_odsp', 'link_odsp', 'adv_stats', 'date', 'league', 'season',
#        'country', 'ht', 'at', 'fthg', 'ftag', 'odd_h', 'odd_d', 'odd_a',
#        'odd_over', 'odd_under', 'odd_bts', 'odd_bts_n'],
#       dtype='object')

# %%
##Construindo um DataFrame com os valores necessários da tabela Ginf
dc = dtt[['id_odsp', 'link_odsp', 'adv_stats', 'date', 'league', 'season',
       'country', 'ht', 'at']]

# %%
associacao = pd.merge(dt_gols, dc, how='inner', on=['id_odsp', 'id_odsp'])

# %%
##Agrupando o quantitativo de gols de cada time por temporada
gols_temporada = associacao.groupby(['event_team', 'season']).count()

# %%
gols_temporada.head(1000)
# Out:
#                           id_odsp  id_event  sort_order  text  event_type  \
# event_team        season
# AC Ajaccio        2012         38        38          38    38          38
#                   2013         36        36          36    36          36
#                   2014         36        36          36    36          36
# AC Milan          2012         68        68          68    68          68
#                   2013         64        64          64    64          64
#                   2014         55        55          55    55          55
#                   2015         54        54          54    54          54
#                   2016         48        48          48    48          48
#                   2017         31        31          31    31          31
# AJ Auxerre        2012         46        46          46    46          46
# AS Monaco         2014         62        62          62    62          62
# ...

# %%
##Agrupando o quantitativo de gols de cada time por temporada
ass_tentativas_temporada = pd.merge(dt_tentativas, dc, how='inner', on=['id_odsp', 'id_odsp'])

# %%
tentativas_temporada = ass_tentativas_temporada.groupby(['event_team', 'season']).count()

# %%
eficiencia = (gols_temporada['id_event']/tentativas_temporada['id_event']) ##Questionar ao professor

# %%
eficiencia.head(1000)
# Out:
# event_team         season
# AC Ajaccio         2012      0.120635
#                    2013      0.098901
#                    2014      0.115016
# AC Milan           2012      0.139344
#                    2013      0.112084
#                    2014      0.100917
#                    2015      0.138817
#                    2016      0.098160
#                    2017      0.122047
# AJ Auxerre         2012      0.115000
# AS Monaco          2014      0.132479
#                    2015      0.125000
#                    2016      0.149425
#                    2017      0.296296
# AS Nancy Lorraine  2012      0.089947
#                    2013      0.090244
#                    2017      0.087912
# AS Roma            2012      0.105647
#                    2013      0.124088
#                    2014      0.133333
#                    2015      0.113248
#                    2016      0.164271
#                    2017      0.130435
# Alaves             2017      0.112583
# ...
