# %%
import pandas as pd

# %%
df = pd.read_csv('football-events\ginf.csv')
dff = pd.read_csv('football-events\events.csv')

# %%
df.count()
# Out:
# id_odsp      10112
# link_odsp    10112
# adv_stats    10112
# date         10112
# league       10112
# season       10112
# country      10112
# ht           10112
# at           10112
# fthg         10112
# ftag         10112
# odd_h        10112
# odd_d        10112
# odd_a        10112
# odd_over       977
# odd_under      977
# odd_bts        977
# odd_bts_n      977
# dtype: int64

# %%
dff.count()
# Out:
# id_odsp          941009
# id_event         941009
# sort_order       941009
# time             941009
# text             941009
# event_type       941009
# event_type2      214293
# side             941009
# event_team       941009
# opponent         941009
# player           880009
# player2          291310
# player_in         51715
# player_out        51738
# shot_place       227459
# shot_outcome     228498
# is_goal          941009
# location         467067
# bodypart         229185
# assist_method    941009
# situation        229137
# fast_break       941009
# dtype: int64

# %%
#Tipo um inner Join entre od dataframes
//pd.merge(df, dff, on=['id_odsp', 'id_odsp'])
# Out:
#   File "<ipython-input-33-030d72889fed>", line 2
#     (/pd.merge(df,, dff,, on=['id_odsp',, 'id_odsp']))
#      ^
# SyntaxError: invalid syntax

# %%
djj = pd.merge(df, dff, on=['id_odsp','id_odsp'])

# %% [markdown]
# #Pegando os registros aos quais foram cartões amarelos, segundo amarelos ou vermelhos
# ##dfcards = dj.loc[(dj['event_type'] == 4) | (dj['event_type'] == 5) | (dj['event_type'] == 6)]

# %%
dfcards = djj[(djj['event_type'] == 6)]

# %% [markdown]
# ##dfcards.groupby(['league', 'date', 'id_odsp']).head()

# %% [markdown]
# ##dj.loc[(dj['league'] == 'D1') & (dj['date'].find('2011') != -1].count()

# %%
djj.head()
# Out:
#      id_odsp                                          link_odsp  adv_stats  \
# 0  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
# 1  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
# 2  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
# 3  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
# 4  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
#
#          date league  season  country                 ht          at  fthg  \
# 0  2011-08-05     D1    2012  germany  Borussia Dortmund  Hamburg SV     3
# 1  2011-08-05     D1    2012  germany  Borussia Dortmund  Hamburg SV     3
# 2  2011-08-05     D1    2012  germany  Borussia Dortmund  Hamburg SV     3
# 3  2011-08-05     D1    2012  germany  Borussia Dortmund  Hamburg SV     3
# 4  2011-08-05     D1    2012  germany  Borussia Dortmund  Hamburg SV     3
#
# ...

# %%
dfcards.head()
# Out:
#         id_odsp                                          link_odsp  adv_stats  \
# 1297  WQGN5NXn/  /soccer/france/ligue-1-2011-2012/nancy-lille-W...       True
# 5236  tl4D8Ggo/  /soccer/france/ligue-1-2011-2012/dijon-lorient...       True
# 5708  fydAFnSc/  /soccer/france/ligue-1-2011-2012/nancy-sochaux...       True
# 6378  0QSBhGQ1/  /soccer/france/ligue-1-2011-2012/lyon-montpell...       True
# 6685  CtEdUSdJ/  /soccer/spain/primera-division-2011-2012/gijon...       True
#
#             date league  season country                 ht             at  \
# 1297  2011-08-06     F1    2012  france  AS Nancy Lorraine          Lille
# 5236  2011-08-20     F1    2012  france          Dijon FCO        Lorient
# 5708  2011-08-21     F1    2012  france  AS Nancy Lorraine        Sochaux
# 6378  2011-08-27     F1    2012  france               Lyon    Montpellier
# 6685  2011-08-27    SP1    2012   spain     Sporting Gijon  Real Sociedad
#
# ...

# %%
df.h
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-3195a88ba51a> in <module>()
# ----> 1 df.h
#
# F:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'h'
