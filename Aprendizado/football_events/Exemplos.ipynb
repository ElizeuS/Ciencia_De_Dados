# %%
import pandas as pd

# %%
##Lê um arquivo ".csv", para ler um "xlsx" .read_excel()
df = pd.read_csv('football-events\ginf.csv')
dff = pd.read_csv('football-events\events.csv')

# %%
#Decreve os dados do DataFrame
df.head()
# Out:
#      id_odsp                                          link_odsp  adv_stats  \
# 0  UFot0hit/  /soccer/germany/bundesliga-2011-2012/dortmund-...       True
# 1  Aw5DflLH/  /soccer/germany/bundesliga-2011-2012/augsburg-...       True
# 2  bkjpaC6n/  /soccer/germany/bundesliga-2011-2012/werder-br...       True
# 3  CzPV312a/  /soccer/france/ligue-1-2011-2012/paris-sg-lori...       True
# 4  GUOdmtII/  /soccer/france/ligue-1-2011-2012/caen-valencie...       True
#
#          date league  season  country                   ht              at  \
# 0  2011-08-05     D1    2012  germany    Borussia Dortmund      Hamburg SV
# 1  2011-08-06     D1    2012  germany          FC Augsburg     SC Freiburg
# 2  2011-08-06     D1    2012  germany        Werder Bremen  Kaiserslautern
# 3  2011-08-06     F1    2012   france  Paris Saint-Germain         Lorient
# 4  2011-08-06     F1    2012   france                 Caen    Valenciennes
#
# ...

# %%
#Decreve os dados do DataFrame
dff.head()
# Out:
#      id_odsp   id_event  sort_order  time  \
# 0  UFot0hit/  UFot0hit1           1     2
# 1  UFot0hit/  UFot0hit2           2     4
# 2  UFot0hit/  UFot0hit3           3     4
# 3  UFot0hit/  UFot0hit4           4     7
# 4  UFot0hit/  UFot0hit5           5     7
#
#                                                 text  event_type  event_type2  \
# 0  Attempt missed. Mladen Petric (Hamburg) left f...           1         12.0
# 1  Corner,  Borussia Dortmund. Conceded by Dennis...           2          NaN
# 2  Corner,  Borussia Dortmund. Conceded by Heiko ...           2          NaN
# 3           Foul by Sven Bender (Borussia Dortmund).           3          NaN
# 4  Gokhan Tore (Hamburg) wins a free kick in the ...           8          NaN
#
#    side         event_team           opponent     ...     player_in  \
# 0     2         Hamburg SV  Borussia Dortmund     ...           NaN
# 1     1  Borussia Dortmund         Hamburg SV     ...           NaN
# ...

# %%
##Contar valores de uma coluna do DatFrame
pd.value_counts(dff['side'])
# Out:
# 1    488224
# 2    452785
# Name: side, dtype: int64

# %%
##Buscar dados com base em uma condição, método ".loc". Para mais condições, deve-se seguir o padrão e adicionar o operador &
dff.loc[(dff['event_team'] == 'Hamburg SV') & (dff['opponent'] == 'Borussia Dortmund')]
##Peguei os jogos do Hamburg SV contra o Borussia Dortmund
# Out:
#           id_odsp     id_event  sort_order  time  \
# 0       UFot0hit/    UFot0hit1           1     2
# 4       UFot0hit/    UFot0hit5           5     7
# 5       UFot0hit/    UFot0hit6           6     9
# 6       UFot0hit/    UFot0hit7           7    10
# 8       UFot0hit/    UFot0hit9           9    11
# 9       UFot0hit/   UFot0hit10          10    13
# 12      UFot0hit/   UFot0hit13          13    14
# 16      UFot0hit/   UFot0hit17          17    20
# 17      UFot0hit/   UFot0hit18          18    20
# 24      UFot0hit/   UFot0hit25          25    27
# 28      UFot0hit/   UFot0hit29          29    31
# 30      UFot0hit/   UFot0hit31          31    32
# 31      UFot0hit/   UFot0hit32          32    32
# 33      UFot0hit/   UFot0hit34          34    33
# 36      UFot0hit/   UFot0hit37          37    36
# 37      UFot0hit/   UFot0hit38          38    38
# 40      UFot0hit/   UFot0hit41          41    42
# 41      UFot0hit/   UFot0hit42          42    42
# ...

# %%
dtf = dff.loc[(dff['event_team'] == 'Hamburg SV') & (dff['opponent'] == 'Borussia Dortmund')]
## .count() retorna a quantidade de registros contidas para cada coluna.
##Nesse caso, solicitei a quantidade de dados para os jogos que foram em casa
dtf[dtf['side'] == 1].count()
# Out:
# id_odsp          296
# id_event         296
# sort_order       296
# time             296
# text             296
# event_type       296
# event_type2       55
# side             296
# event_team       296
# opponent         296
# player           274
# player2           70
# player_in         15
# player_out        15
# shot_place        53
# shot_outcome      53
# is_goal          296
# location         125
# bodypart          54
# assist_method    296
# situation         54
# fast_break       296
# dtype: int64

# %%
##Plota um gráfico para uma coluna específica com o método .plot(). Quando não define os dois eixos, ele cria o eixo x baseado na quantidade de registros
df['odd_h'].plot()

# %%
#Plotando um gráfico, definindo os dois eixos, o tipo do gráfico, o título e a cor.
df.plot(x='odd_h',y='fthg', kind='scatter', title='Odd_h x fthg',color='green');
#Para criar um histograma de frequencias, coloca dataframe['column'].hist(bins=100), define o tamanho do beans

# %%
dtf.columns
# Out:
# Index(['id_odsp', 'id_event', 'sort_order', 'time', 'text', 'event_type',
#        'event_type2', 'side', 'event_team', 'opponent', 'player', 'player2',
#        'player_in', 'player_out', 'shot_place', 'shot_outcome', 'is_goal',
#        'location', 'bodypart', 'assist_method', 'situation', 'fast_break'],
#       dtype='object')

# %%
#Tirar a média dos valores de uma coluna
df['odd_a'].mean()
# Out:
# 5.5375445015822775

# %%
#Obtém o valor máximo dos valores de uma coluna
df['odd_a'].max()
# Out:
# 81.0

# %%
#Obtém o valor mínimo dos valores de uma coluna
df['odd_a'].min()
# Out:
# 1.1100000000000001

# %%
#Calcula o valor do desvio padrão dos valores de uma coluna
df['odd_a'].std()
# Out:
# 5.7004850037528625

# %%
#Obter todos os valores juntos
df['odd_a'].describe()
# Out:
# count    10112.000000
# mean         5.537545
# std          5.700485
# min          1.110000
# 25%          2.740000
# 50%          3.860000
# 75%          6.000000
# max         81.000000
# Name: odd_a, dtype: float64

# %%
#Plota um gráfico do tipo BOX para a obtenção de OUTLIERS
df.boxplot(column='odd_a', by='season')
# Out:
# F:\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
##Comando sort_values(['atributo']) ordena os valores por coluna.
dtf.loc[(dtf['event_type'] == 7)].sort_values(['time'])
# Out:
#           id_odsp     id_event  sort_order  time  \
# 604917  EZfDwAop/   EZfDwAop12          12    18
# 722189  04GXLvyK/   04GXLvyK30          30    29
# 894818  OMLpTOKu/   OMLpTOKu34          34    31
# 823107  nVijLG3h/   nVijLG3h35          35    35
# 41      UFot0hit/   UFot0hit42          42    42
# 75934   C0n2lMHR/   C0n2lMHR52          52    45
# 314919  2ZNAciJS/   2ZNAciJS61          61    45
# 46      UFot0hit/   UFot0hit47          47    47
# 894842  OMLpTOKu/   OMLpTOKu61          61    52
# 823125  nVijLG3h/   nVijLG3h53          53    54
# 604971  EZfDwAop/   EZfDwAop66          66    60
# 244074  QZJ4hsvn/   QZJ4hsvn85          85    63
# 75956   C0n2lMHR/   C0n2lMHR74          74    65
# 513970  tCcPOhJO/   tCcPOhJO68          68    66
# 823133  nVijLG3h/   nVijLG3h61          61    67
# 314961  2ZNAciJS/  2ZNAciJS103         103    68
# 894867  OMLpTOKu/   OMLpTOKu87          87    69
# 167181  MT3VDKVr/   MT3VDKVr83          83    69
# ...
